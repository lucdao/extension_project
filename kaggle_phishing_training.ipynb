# %%
# !nvidia-smi

# %%
# !pip install torch torchvision pillow scikit-learn

# %%
# Upload dataset_phishing.csv and preprocess.py and train.py manually in Kaggle Files
from google.colab import files

# %%
# !python preprocess.py

# %%
# !python train.py
